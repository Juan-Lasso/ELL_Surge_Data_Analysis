# %%
## import pandas 
import pandas as pd

# %%
## let's read the file 
df = pd.read_excel("raw-data/Demographic_Snapshot_ENL.xlsx", sheet_name = "School")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9363 entries, 0 to 9362
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DBN                             9363 non-null   object
#  1   School Name                     9363 non-null   object
#  2   Year                            9363 non-null   object
#  3   Total Enrollment                9363 non-null   int64
#  4   Grade 3K                        9363 non-null   int64
#  5   Grade PK (Half Day & Full Day)  9363 non-null   int64
#  6   Grade K                         9363 non-null   int64
#  7   Grade 1                         9363 non-null   int64
#  8   Grade 2                         9363 non-null   int64
#  9   Grade 3                         9363 non-null   int64
#  10  Grade 4                         9363 non-null   int64
#  11  Grade 5                         9363 non-null   int64
#  12  Grade 6                         9363 non-null   int64
#  13  Grade 7                         9363 non-null   int64
#  14  Grade 8                         9363 non-null   int64
#  15  Grade 9                         9363 non-null   int64
#  16  Grade 10                        9363 non-null   int64
#  17  Grade 11                        9363 non-null   int64
#  18  Grade 12                        9363 non-null   int64
#  19  # Female                        9363 non-null   int64
#  20  % Female                        9363 non-null   float64
#  21  # Male                          9363 non-null   int64
#  22  % Male                          9363 non-null   float64
#  23  # Neither Female nor Male       3774 non-null   float64
#  24  % Neither Female nor Male       3774 non-null   float64
#  25  # Asian                         9363 non-null   int64
#  26  % Asian                         9363 non-null   float64
#  27  # Black                         9363 non-null   int64
#  28  % Black                         9363 non-null   float64
#  29  # Hispanic                      9363 non-null   int64
#  30  % Hispanic                      9363 non-null   float64
#  31  # Multi-Racial                  9363 non-null   int64
#  32  % Multi-Racial                  9363 non-null   float64
#  33  # Native American               9363 non-null   int64
#  34  % Native American               9363 non-null   float64
#  35  # White                         9363 non-null   int64
#  36  % White                         9363 non-null   float64
#  37  # Missing Race/Ethnicity Data   9363 non-null   int64
#  38  % Missing Race/Ethnicity Data   9363 non-null   float64
#  39  # Students with Disabilities    9363 non-null   int64
#  40  % Students with Disabilities    9363 non-null   float64
#  41  # English Language Learners     9363 non-null   int64
#  42  % English Language Learners     9363 non-null   float64
#  43  # Poverty                       9363 non-null   object
#  44  % Poverty                       9363 non-null   object
#  45  Economic Need Index             9363 non-null   object
# dtypes: float64(13), int64(27), object(6)
# memory usage: 3.3+ MB

# %%
## Let's now test the data for any relevant duplicates 
# Clean School Name for consistency
df["School Name"] = (
    df["School Name"]
    .str.lower()
    .str.strip()
    .str.replace(r'[^\w\s]', '', regex=True)
)

# Clean Year column by stripping whitespace
df["Year"] = df["Year"].str.strip()

# Count duplicates for each School Name + Year pair (for overview)
duplicate_counts = df.groupby(["School Name", "Year"]).size().reset_index(name="counts")
duplicates_in_school_year = duplicate_counts[duplicate_counts["counts"] > 1]

print(f"Number of duplicated school-year entries (by School Name): {duplicates_in_school_year.shape[0]}")
print(duplicates_in_school_year)

# Find true duplicate records by DBN + Year (exact duplicates)
duplicates = df[df.duplicated(subset=["DBN", "Year"], keep=False)]

print(f"Number of true duplicate DBN-year records: {duplicates.shape[0]}")
print(duplicates)
# Out:
# Number of duplicated school-year entries (by School Name): 20
#                                             School Name     Year  counts
# 3852  new visions charter high school for advanced math  2019-20       4
# 3853  new visions charter high school for advanced math  2020-21       4
# 3854  new visions charter high school for advanced math  2021-22       4
# 3855  new visions charter high school for advanced math  2022-23       4
# 3856  new visions charter high school for advanced math  2023-24       4
# 3857  new visions charter high school for the humani...  2019-20       3
# 3858  new visions charter high school for the humani...  2020-21       3
# 3859  new visions charter high school for the humani...  2021-22       3
# 3860  new visions charter high school for the humani...  2022-23       3
# 3861  new visions charter high school for the humani...  2023-24       3
# 6974                                             ps 360  2019-20       2
# 6975                                             ps 360  2020-21       2
# 6976                                             ps 360  2021-22       2
# 6977                                             ps 360  2022-23       2
# 6978                                             ps 360  2023-24       2
# 7014                                             ps 376  2019-20       2
# 7015                                             ps 376  2020-21       2
# 7016                                             ps 376  2021-22       2
# 7017                                             ps 376  2022-23       2
# 7018                                             ps 376  2023-24       2
# Number of true duplicate DBN-year records: 0
# Empty DataFrame
# Columns: [DBN, School Name, Year, Total Enrollment, Grade 3K, Grade PK (Half Day & Full Day), Grade K, Grade 1, Grade 2, Grade 3, Grade 4, Grade 5, Grade 6, Grade 7, Grade 8, Grade 9, Grade 10, Grade 11, Grade 12, # Female, % Female, # Male, % Male, # Neither Female nor Male, % Neither Female nor Male, # Asian, % Asian, # Black, % Black, # Hispanic, % Hispanic, # Multi-Racial, % Multi-Racial, # Native American, % Native American, # White, % White, # Missing Race/Ethnicity Data, % Missing Race/Ethnicity Data, # Students with Disabilities, % Students with Disabilities, # English Language Learners, % English Language Learners, # Poverty, % Poverty, Economic Need Index]
# Index: []
#
# [0 rows x 46 columns]

# %% [markdown]
# In our analysis, we found that while some school names appear multiple times with different DBN codes (unique identifiers), there are no true duplicates when considering the combination of DBN and Year. Since no DBN-Year pairs are repeated, our dataset is confirmed to be accurate and reliable for further use.

# %%
## let's eliminate unwanted columns 
df_clean = df[["School Name", "Year", "Total Enrollment", "# English Language Learners", "% English Language Learners"]]
df_clean
# Out:
#                             School Name     Year  Total Enrollment  \
# 0               ps 015 roberto clemente  2019-20               190
# 1               ps 015 roberto clemente  2020-21               193
# 2               ps 015 roberto clemente  2021-22               179
# 3               ps 015 roberto clemente  2022-23               180
# 4               ps 015 roberto clemente  2023-24               189
# ...                                 ...      ...               ...
# 9358  bronx charter school for the arts  2019-20               523
# 9359  bronx charter school for the arts  2020-21               626
# 9360  bronx charter school for the arts  2021-22               598
# 9361  bronx charter school for the arts  2022-23               591
# 9362  bronx charter school for the arts  2023-24               624
#
#       # English Language Learners  % English Language Learners
# 0                              17                     0.089474
# 1                              21                     0.108808
# 2                              11                     0.061453
# 3                              12                     0.066667
# 4                              24                     0.126984
# ...                           ...                          ...
# 9358                           69                     0.131931
# 9359                           78                     0.124601
# 9360                           79                     0.132107
# 9361                           73                     0.123519
# 9362                           70                     0.112179
#
# [9363 rows x 5 columns]

# %%
## to improve readability, let's define each year range using the column name 'Start Year' 
df_clean['Start Year'] = df_clean['Year'].str.extract(r'(\d{4})').astype(int)
df_clean
# Out:
# /var/folders/6p/9zpd5gjx1dj6zpc834rhv6d40000gn/T/ipykernel_98100/612969100.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Start Year'] = df_clean['Year'].str.extract(r'(\d{4})').astype(int)
#                             School Name     Year  Total Enrollment  \
# 0               ps 015 roberto clemente  2019-20               190
# 1               ps 015 roberto clemente  2020-21               193
# 2               ps 015 roberto clemente  2021-22               179
# 3               ps 015 roberto clemente  2022-23               180
# 4               ps 015 roberto clemente  2023-24               189
# ...                                 ...      ...               ...
# 9358  bronx charter school for the arts  2019-20               523
# 9359  bronx charter school for the arts  2020-21               626
# 9360  bronx charter school for the arts  2021-22               598
# 9361  bronx charter school for the arts  2022-23               591
# 9362  bronx charter school for the arts  2023-24               624
#
#       # English Language Learners  % English Language Learners  Start Year
# 0                              17                     0.089474        2019
# 1                              21                     0.108808        2020
# 2                              11                     0.061453        2021
# 3                              12                     0.066667        2022
# 4                              24                     0.126984        2023
# ...                           ...                          ...         ...
# 9358                           69                     0.131931        2019
# 9359                           78                     0.124601        2020
# 9360                           79                     0.132107        2021
# 9361                           73                     0.123519        2022
# 9362                           70                     0.112179        2023
#
# [9363 rows x 6 columns]

# %%
## Now, we'll generate a pivot table with school years as column values

school_ell_trends = df_clean.pivot_table(
    index='School Name',
    columns='Start Year',
    values='# English Language Learners'
)
school_ell_trends
# Out:
# Start Year                                           2019   2020   2021  \
# School Name
# 47 the american sign language and english secondar   11.0   15.0    9.0
# a philip randolph campus high school                185.0  223.0  216.0
# a school without walls                                NaN    NaN    NaN
# abraham lincoln high school                         251.0  272.0  278.0
# academic leadership charter school                   75.0   83.0   73.0
# ...                                                   ...    ...    ...
# young womens leadership school queens                10.0   18.0   15.0
# zeta charter school  mount eden                       NaN    4.0   44.0
# zeta charter school  tremont park                     NaN    3.0   24.0
# zeta charter schools  inwood                         42.0   59.0   89.0
# zeta charter schools  south bronx                    21.0   26.0   45.0
#
# Start Year                                           2022   2023
# School Name
# 47 the american sign language and english secondar    8.0   12.0
# a philip randolph campus high school                176.0  195.0
# a school without walls                                NaN    3.0
# abraham lincoln high school                         309.0  321.0
# academic leadership charter school                   52.0   46.0
# ...                                                   ...    ...
# young womens leadership school queens                26.0   42.0
# zeta charter school  mount eden                      66.0   93.0
# zeta charter school  tremont park                    37.0   37.0
# zeta charter schools  inwood                         87.0   65.0
# zeta charter schools  south bronx                    57.0   70.0
#
# [1886 rows x 5 columns]

# %%
school_ell_trends.head()
# Out:
# Start Year                                           2019  2020  2021  2022  \
# School Name
# 47 the american sign language and english secondar   11.0   NaN   NaN   NaN
# a philip randolph campus high school                185.0   NaN   NaN   NaN
# a school without walls                                NaN   NaN   NaN   NaN
# abraham lincoln high school                         251.0   NaN   NaN   NaN
# academic leadership charter school                   75.0   NaN   NaN   NaN
#
# Start Year                                          2023
# School Name
# 47 the american sign language and english secondar   NaN
# a philip randolph campus high school                 NaN
# a school without walls                               3.0
# abraham lincoln high school                          NaN
# academic leadership charter school                   NaN

# %%
# How many unique schools are in the filtered DataFrame?
# let's check to see the data is accurate 
original_school_count = df_clean['School Name'].nunique()
original_school_count
# Out:
# 1886

# %%
# How many schools made it into the pivot table?
# let's check to see the data is accurate 
pivot_school_count = school_ell_trends.shape[0]
pivot_school_count
# Out:
# 1886

# %%
## Let's replace the NaN values with 0 
school_ell_trends = school_ell_trends.fillna(0)
school_ell_trends
# Out:
# Start Year                                           2019   2020   2021  \
# School Name
# 47 the american sign language and english secondar   11.0   15.0    9.0
# a philip randolph campus high school                185.0  223.0  216.0
# a school without walls                                0.0    0.0    0.0
# abraham lincoln high school                         251.0  272.0  278.0
# academic leadership charter school                   75.0   83.0   73.0
# ...                                                   ...    ...    ...
# young womens leadership school queens                10.0   18.0   15.0
# zeta charter school  mount eden                       0.0    4.0   44.0
# zeta charter school  tremont park                     0.0    3.0   24.0
# zeta charter schools  inwood                         42.0   59.0   89.0
# zeta charter schools  south bronx                    21.0   26.0   45.0
#
# Start Year                                           2022   2023
# School Name
# 47 the american sign language and english secondar    8.0   12.0
# a philip randolph campus high school                176.0  195.0
# a school without walls                                0.0    3.0
# abraham lincoln high school                         309.0  321.0
# academic leadership charter school                   52.0   46.0
# ...                                                   ...    ...
# young womens leadership school queens                26.0   42.0
# zeta charter school  mount eden                      66.0   93.0
# zeta charter school  tremont park                    37.0   37.0
# zeta charter schools  inwood                         87.0   65.0
# zeta charter schools  south bronx                    57.0   70.0
#
# [1886 rows x 5 columns]

# %%
## Percentage change between (2021 - 2022) and (2022 - 2023)
school_ell_trends['Change_2021_2022'] = ((school_ell_trends[2022] - school_ell_trends[2021]) / school_ell_trends[2021]) * 100

## Percentage change between (2022 - 2023) and (2023 - 2024)
school_ell_trends['Change_2022_2023'] = ((school_ell_trends[2023] - school_ell_trends[2022]) / school_ell_trends[2022]) * 100

## Display updated DataFrame
school_ell_trends
# Out:
# Start Year                                           2019   2020   2021  \
# School Name
# 47 the american sign language and english secondar   11.0   15.0    9.0
# a philip randolph campus high school                185.0  223.0  216.0
# a school without walls                                0.0    0.0    0.0
# abraham lincoln high school                         251.0  272.0  278.0
# academic leadership charter school                   75.0   83.0   73.0
# ...                                                   ...    ...    ...
# young womens leadership school queens                10.0   18.0   15.0
# zeta charter school  mount eden                       0.0    4.0   44.0
# zeta charter school  tremont park                     0.0    3.0   24.0
# zeta charter schools  inwood                         42.0   59.0   89.0
# zeta charter schools  south bronx                    21.0   26.0   45.0
#
# Start Year                                           2022   2023  \
# School Name
# 47 the american sign language and english secondar    8.0   12.0
# a philip randolph campus high school                176.0  195.0
# a school without walls                                0.0    3.0
# abraham lincoln high school                         309.0  321.0
# academic leadership charter school                   52.0   46.0
# ...                                                   ...    ...
# young womens leadership school queens                26.0   42.0
# zeta charter school  mount eden                      66.0   93.0
# zeta charter school  tremont park                    37.0   37.0
# zeta charter schools  inwood                         87.0   65.0
# zeta charter schools  south bronx                    57.0   70.0
#
# Start Year                                          Change_2021_2022  \
# School Name
# 47 the american sign language and english secondar        -11.111111
# a philip randolph campus high school                      -18.518519
# a school without walls                                           NaN
# abraham lincoln high school                                11.151079
# academic leadership charter school                        -28.767123
# ...                                                              ...
# young womens leadership school queens                      73.333333
# zeta charter school  mount eden                            50.000000
# zeta charter school  tremont park                          54.166667
# zeta charter schools  inwood                               -2.247191
# zeta charter schools  south bronx                          26.666667
#
# Start Year                                          Change_2022_2023
# School Name
# 47 the american sign language and english secondar         50.000000
# a philip randolph campus high school                       10.795455
# a school without walls                                           inf
# abraham lincoln high school                                 3.883495
# academic leadership charter school                        -11.538462
# ...                                                              ...
# young womens leadership school queens                      61.538462
# zeta charter school  mount eden                            40.909091
# zeta charter school  tremont park                           0.000000
# zeta charter schools  inwood                              -25.287356
# zeta charter schools  south bronx                          22.807018
#
# [1886 rows x 7 columns]

# %%
## Filter out rows where the base year is zero or where the change is infinite
valid_2021_2022 = school_ell_trends['Change_2021_2022'].replace([float('inf'), -float('inf')], pd.NA).dropna()
valid_2022_2023 = school_ell_trends['Change_2022_2023'].replace([float('inf'), -float('inf')], pd.NA).dropna()

## Calculate mean of the cleaned columns
avg_change_2021_2022 = valid_2021_2022.mean()
avg_change_2022_2023 = valid_2022_2023.mean()

# %%
#average rate of change between 2021-2022 and 2022-2023 where you saw the beginning of the immigration influx
avg_change_2021_2022
# Out:
# 8.634362922908755

# %%
#average rate of change between 2022-2023 and 2023-2024 where you saw an ongoing increase of immigrant children 
avg_change_2022_2023
# Out:
# 25.659581642469096

# %%
##Highest to lowest based on the percent change in ENL enrollment between 2022 and 2023
import numpy as np

## Replace 0 with np.nan in 2022 before calculating percent change
school_ell_trends['Change_2022_2023'] = (
    (school_ell_trends[2023] - school_ell_trends[2022].replace(0, np.nan)) /
    school_ell_trends[2022].replace(0, np.nan)
) * 100

## Drop rows with NaN or inf in the change column
school_ell_trends_cleaned = school_ell_trends.replace([np.inf, -np.inf], np.nan).dropna(subset=['Change_2022_2023'])

## Sort from highest to lowest
school_ell_trends_sorted = school_ell_trends_cleaned.sort_values(by='Change_2022_2023', ascending=False)

## View top 10 results
school_ell_trends_sorted.head(11)
# Out:
# Start Year                                          2019  2020  2021  2022  \
# School Name
# ps 064 robert simon                                  4.0   4.0   3.0   2.0
# ps 306 ethan allen                                   4.0   2.0   3.0   2.0
# ps 333 manhattan school for children                16.0  12.0  11.0   7.0
# olympus academy                                      4.0   3.0   3.0   1.0
# the riverside school for makers and artists         23.0  29.0  21.0  24.0
# lower manhattan community middle school             17.0  20.0  14.0   6.0
# university neighborhood middle school               11.0   8.0   5.0   4.0
# the peck slip school                                 8.0   8.0  13.0  12.0
# mosaic preparatory academy                          20.0  20.0  12.0  11.0
# ps 242  the young diplomats magnet academy          11.0  13.0   7.0  14.0
# cultural arts academy charter school at spring cre   1.0   1.0   2.0   4.0
#
# Start Year                                           2023  Change_2021_2022  \
# School Name
# ps 064 robert simon                                  25.0        -33.333333
# ps 306 ethan allen                                   22.0        -33.333333
# ps 333 manhattan school for children                 67.0        -36.363636
# olympus academy                                       8.0        -66.666667
# the riverside school for makers and artists         182.0         14.285714
# lower manhattan community middle school              42.0        -57.142857
# university neighborhood middle school                27.0        -20.000000
# the peck slip school                                 80.0         -7.692308
# mosaic preparatory academy                           70.0         -8.333333
# ps 242  the young diplomats magnet academy           88.0        100.000000
# cultural arts academy charter school at spring cre   25.0        100.000000
#
# Start Year                                          Change_2022_2023
# School Name
# ps 064 robert simon                                      1150.000000
# ps 306 ethan allen                                       1000.000000
# ps 333 manhattan school for children                      857.142857
# olympus academy                                           700.000000
# the riverside school for makers and artists               658.333333
# lower manhattan community middle school                   600.000000
# university neighborhood middle school                     575.000000
# the peck slip school                                      566.666667
# mosaic preparatory academy                                536.363636
# ps 242  the young diplomats magnet academy                528.571429
# cultural arts academy charter school at spring cre        525.000000

# %%
# Now let's do total enrollment per year
total_enrollment = school_ell_trends[[2019, 2020, 2021, 2022, 2023]].sum()
total_enrollment
# Out:
# Start Year
# 2019    141529.583333
# 2020    145869.500000
# 2021    146285.583333
# 2022    148040.916667
# 2023    162951.666667
# dtype: float64

# %%
school_ell_trends_sorted.head(26)
# Out:
# Start Year                                          2019  2020  2021  2022  \
# School Name
# ps 064 robert simon                                  4.0   4.0   3.0   2.0
# ps 306 ethan allen                                   4.0   2.0   3.0   2.0
# ps 333 manhattan school for children                16.0  12.0  11.0   7.0
# olympus academy                                      4.0   3.0   3.0   1.0
# the riverside school for makers and artists         23.0  29.0  21.0  24.0
# lower manhattan community middle school             17.0  20.0  14.0   6.0
# university neighborhood middle school               11.0   8.0   5.0   4.0
# the peck slip school                                 8.0   8.0  13.0  12.0
# mosaic preparatory academy                          20.0  20.0  12.0  11.0
# ps 242  the young diplomats magnet academy          11.0  13.0   7.0  14.0
# cultural arts academy charter school at spring cre   1.0   1.0   2.0   4.0
# the star academy  ps63                               5.0   3.0   3.0   5.0
# ps 096 joseph lanzetta                              74.0  67.0  47.0  29.0
# school for global leaders                           17.0  23.0  21.0  11.0
# harbor science and arts charter school               5.0   5.0   9.0  10.0
# success academy charter school  fort greene         15.0  11.0   7.0   4.0
# ps 102 jacques cartier                              28.0  22.0  19.0  18.0
# the childrens workshop school                       13.0  12.0   6.0   9.0
# collegiate academy for mathematics and personal aw   0.0   1.0   1.0   2.0
# east flatbush ascend charter school                  2.0   3.0   4.0   3.0
# ps 134 henrietta szold                              18.0  12.0   8.0  10.0
# new design middle school                             4.0   4.0   3.0   4.0
# gotham tech high school                              0.0   0.0   0.0   7.0
# ps 140 nathan straus                                27.0  26.0  27.0  23.0
# ps 108 assemblyman angelo del toro educational c    29.0  32.0  26.0  22.0
# ps 223 lyndon b johnson                             30.0  32.0  41.0  51.0
#
# Start Year                                           2023  Change_2021_2022  \
# School Name
# ps 064 robert simon                                  25.0        -33.333333
# ps 306 ethan allen                                   22.0        -33.333333
# ps 333 manhattan school for children                 67.0        -36.363636
# olympus academy                                       8.0        -66.666667
# the riverside school for makers and artists         182.0         14.285714
# lower manhattan community middle school              42.0        -57.142857
# university neighborhood middle school                27.0        -20.000000
# the peck slip school                                 80.0         -7.692308
# mosaic preparatory academy                           70.0         -8.333333
# ps 242  the young diplomats magnet academy           88.0        100.000000
# cultural arts academy charter school at spring cre   25.0        100.000000
# the star academy  ps63                               31.0         66.666667
# ps 096 joseph lanzetta                              169.0        -38.297872
# school for global leaders                            63.0        -47.619048
# harbor science and arts charter school               56.0         11.111111
# success academy charter school  fort greene          21.0        -42.857143
# ps 102 jacques cartier                               92.0         -5.263158
# the childrens workshop school                        46.0         50.000000
# collegiate academy for mathematics and personal aw   10.0        100.000000
# east flatbush ascend charter school                  15.0        -25.000000
# ps 134 henrietta szold                               48.0         25.000000
# new design middle school                             19.0         33.333333
# gotham tech high school                              32.0               NaN
# ps 140 nathan straus                                105.0        -14.814815
# ps 108 assemblyman angelo del toro educational c     98.0        -15.384615
# ps 223 lyndon b johnson                             224.0         24.390244
#
# Start Year                                          Change_2022_2023
# School Name
# ps 064 robert simon                                      1150.000000
# ps 306 ethan allen                                       1000.000000
# ps 333 manhattan school for children                      857.142857
# olympus academy                                           700.000000
# the riverside school for makers and artists               658.333333
# lower manhattan community middle school                   600.000000
# university neighborhood middle school                     575.000000
# the peck slip school                                      566.666667
# mosaic preparatory academy                                536.363636
# ps 242  the young diplomats magnet academy                528.571429
# cultural arts academy charter school at spring cre        525.000000
# the star academy  ps63                                    520.000000
# ps 096 joseph lanzetta                                    482.758621
# school for global leaders                                 472.727273
# harbor science and arts charter school                    460.000000
# success academy charter school  fort greene               425.000000
# ps 102 jacques cartier                                    411.111111
# the childrens workshop school                             411.111111
# collegiate academy for mathematics and personal aw        400.000000
# east flatbush ascend charter school                       400.000000
# ps 134 henrietta szold                                    380.000000
# new design middle school                                  375.000000
# gotham tech high school                                   357.142857
# ps 140 nathan straus                                      356.521739
# ps 108 assemblyman angelo del toro educational c          345.454545
# ps 223 lyndon b johnson                                   339.215686
